# %% [markdown]
# ## Rescale the model from paper
# Values from paper are primed.
#
# $\tau = 10^{-3}s$
#
# $\kappa' = \xi'^2/\tau'$
#
# $\kappa = 9.96\times10^{-4}cm^2/s$
#
# Therefore:
# $\xi = \sqrt{0.996}cm = 0.998cm$
#
# $D = 230*2*\xi = 459cm$
#
# $\Omega_0 = 4\pi\times10^{-3}\tau^{-1} = 4\pi s^{-1}$
#
# $\dot{\Omega} = 2.5\pi\times10^{-8}\tau^{-2} = 2.5\pi\times10^{-2}s^{-2}$
#
# $T = 44.5s$
